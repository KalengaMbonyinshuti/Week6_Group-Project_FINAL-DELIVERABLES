# %%
# %run spotify_client.py

# %%
# %run song_recommender.py

# %%
song_recommender()
# Out:
# Write the song name:que beleza
# Write the artist name:tim maia
# 1: The name of song is: 'Que Beleza' and the artist is: Tim Maia
# 2: The name of song is: 'Que Beleza' and the artist is: Tim Maia
# 3: The name of song is: 'Imunização Racional (Que Beleza)' and the artist is: Tim Maia
# 4: The name of song is: 'Imunização Racional (Que Beleza)' and the artist is: Tim Maia
#
#  Please type the number of your selection:1
#
#  You selected Que Beleza from Tim Maia
#
#  Your mood is Melancholic
#  We think you will like this song:
#  la tendresse from
#  andre bourvil
#  Listen on https://open.spotify.com/track/7jKGXLcFqmRytiKFJC3d2C
#
#  Do you want to receive another suggestion [y/n]n
#
#  We hope you are happy!
#
#  Thank you!
